# %%
import cProfile as cP
import re
help(cP)
# Out:
# Help on module cProfile:
#
# NAME
#     cProfile
#
# DESCRIPTION
#     Python interface for the 'lsprof' profiler.
#     Compatible with the 'profile' module.
#
# CLASSES
#     _lsprof.Profiler(builtins.object)
#         Profile
#
#     class Profile(_lsprof.Profiler)
#      |  Profile(custom_timer=None, time_unit=None, subcalls=True, builtins=True)
#      |
#      |  Builds a profiler object using the specified timer function.
#      |  The default timer is a fast built-in one based on real time.
#      |  For custom timer functions returning integers, time_unit can
#      |  be a float specifying a scale (i.e. how long each integer unit
#      |  is, in seconds).
#      |
#      |  Method resolution order:
#      |      Profile
#      |      _lsprof.Profiler
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  create_stats(self)
#      |
#      |  dump_stats(self, file)
#      |
#      |  print_stats(self, sort=-1)
#      |
# ...

# %%
help(re)
# Out:
# Help on module re:
#
# NAME
#     re - Support for regular expressions (RE).
#
# DESCRIPTION
#     This module provides regular expression matching operations similar to
#     those found in Perl.  It supports both 8-bit and Unicode strings; both
#     the pattern and the strings being processed can contain null bytes and
#     characters outside the US ASCII range.
#
#     Regular expressions can contain both special and ordinary characters.
#     Most ordinary characters, like "A", "a", or "0", are the simplest
#     regular expressions; they simply match themselves.  You can
#     concatenate ordinary characters, so last matches the string 'last'.
#
#     The special characters are:
#         "."      Matches any character except a newline.
#         "^"      Matches the start of the string.
#         "$"      Matches the end of the string or just before the newline at
#                  the end of the string.
# ...

# %%
from one_simulation import R_one_simulation
def truncator(x = 1.0/3,n = 10000):
    from math import trunc
    for i in range(n):
        trunc(x)
        
def rounder(x = 1.0/3,n = 10000):
    for i in range(n):
        round(x,2)
    
cProfile.run('rounder()')
#R_one_simulation()


#10006 function calls in 0.007 seconds for trunc
#stepProfile = cP.Profile()
#stepProflie.runcall(f)
# Out:
#          10004 function calls in 0.022 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.004    0.004    0.022    0.022 <ipython-input-30-9f749091c6b7>:7(rounder)
#         1    0.000    0.000    0.022    0.022 <string>:1(<module>)
#         1    0.000    0.000    0.022    0.022 {built-in method builtins.exec}
#     10000    0.018    0.000    0.018    0.000 {built-in method builtins.round}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-7bcbe02f9790> in <module>()
#       1 from one_simulation import R_one_simulation
# ----> 2 cProfile.runctx('R_one_simulation()')
#
# TypeError: runctx() missing 2 required positional arguments: 'globals' and 'locals'

# %%
from math import trunc
help(trunc)
# Out:
# Help on built-in function trunc in module math:
#
# trunc(...)
#     trunc(x:Real) -> Integral
#
#     Truncates x to the nearest Integral toward 0. Uses the __trunc__ magic method.
